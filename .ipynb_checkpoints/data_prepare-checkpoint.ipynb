# %% [markdown]
# # Prepare Data
#
# - Import

# %%
from huggingface_hub import hf_hub_download

# %% [markdown]
# ## Yelp18
#
# + **Dataset description:**
#
#   The data statistics are summarized as follows:
#
#   | Dataset ID          | #Users | #Items | #Interactions |  #Train   |  #Test  | Density |
#   | :-------: | :----: | :----: | :-----------: | :-------: | :-----: | :-----: |
#   | Yelp18_m1 | 31,668 | 38,048 |   1,561,406   | 1,237,259 | 324,147 | 0.00130 |
#
#
# + **Data format:**
# user_id item1 item2 ...
#
# + **Source:** https://www.yelp.com/dataset
# + **Download:** https://huggingface.co/datasets/reczoo/Yelp18_m1/tree/main
# + **RecZoo Datasets:** https://github.com/reczoo/Datasets
#
# + **Check the md5sum for data integrity:**
#     ```bash
#     $ md5sum *.txt
#     520fe559761ff2c654629201c807f353  item_list.txt
#     0d57d7399862c32152b045ec5d2698e7  test.txt
#     1b8b5d22a227e01d6de002c53d32b4c4  train.txt
#     ae4f810cd6e827f10fc418753c7d92f9  user_list.txt
#     ```

# %% [markdown]
# - Train data

# %%
hf_hub_download(repo_id="reczoo/Yelp18_m1", filename="train.txt", repo_type="dataset", cache_dir="./data/Yelp18_m1")
# Out:
# './data/Yelp18_m1/datasets--reczoo--Yelp18_m1/snapshots/8c6e8b56e5a674b3b60ed859a617cb001b8280d0/train.txt'

# %% [markdown]
# - Test data

# %%
hf_hub_download(repo_id="reczoo/Yelp18_m1", filename="test.txt", repo_type="dataset", cache_dir="./data/Yelp18_m1")
# Out:
# './data/Yelp18_m1/datasets--reczoo--Yelp18_m1/snapshots/8c6e8b56e5a674b3b60ed859a617cb001b8280d0/test.txt'

# %% [markdown]
# - move data

# %%
# !cp -f /home/jovyan/UltraGCN/data/Yelp18_m1/datasets--reczoo--Yelp18_m1/snapshots/8c6e8b56e5a674b3b60ed859a617cb001b8280d0/train.txt /home/jovyan/UltraGCN/data/Yelp18_m1/

# !cp -f /home/jovyan/UltraGCN/data/Yelp18_m1/datasets--reczoo--Yelp18_m1/snapshots/8c6e8b56e5a674b3b60ed859a617cb001b8280d0/test.txt /home/jovyan/UltraGCN/data/Yelp18_m1/

# %% [markdown]
# ## Gowalla_m1
#
# + **Dataset description:**
#
#   The dataset statistics are summarized as follows:
#
#   | Dataset ID         | #Users | #Items | #Interactions |   #Train  |  #Test  | Density |
#   |:--------------:|:------:|:------:|:-------------:|:---------:|:-------:|:-------:|
#   | Gowalla_m1 | 29,858  | 40,981  |  1,027,370    | 810,128  | 217,242  |  0.00084  |
#
# + **Source:** https://snap.stanford.edu/data/loc-gowalla.html
# + **Download:** https://huggingface.co/datasets/reczoo/Gowalla_m1/tree/main
# + **RecZoo Datasets:** https://github.com/reczoo/Datasets
#
# + **Check the md5sum for data integrity:**
#   ```bash
#   $ md5sum *.txt
#   13b1c0d75b07b8cea9413f40042f476f  item_list.txt
#   c04e2c4bcd2389f53ed8281816166149  test.txt
#   5eec1eb2edb8dd648377d348b8e136cf  train.txt
#   f83ec6f2cd974ba6470e8808830cc144  user_list.txt
#   ```

# %% [markdown]
# - Train data

# %%
hf_hub_download(repo_id="reczoo/Gowalla_m1", filename="train.txt", repo_type="dataset", cache_dir="./data/Gowalla_m1")
# Out:
# train.txt:   0%|          | 0.00/4.63M [00:00<?, ?B/s]
# './data/Gowalla_m1/datasets--reczoo--Gowalla_m1/snapshots/d18cf8efd0f159548cd674c7320ca9e39046acb8/train.txt'

# %% [markdown]
# - Test data

# %%
hf_hub_download(repo_id="reczoo/Gowalla_m1", filename="test.txt", repo_type="dataset", cache_dir="./data/Gowalla_m1")
# Out:
# test.txt:   0%|          | 0.00/1.37M [00:00<?, ?B/s]
# './data/Gowalla_m1/datasets--reczoo--Gowalla_m1/snapshots/d18cf8efd0f159548cd674c7320ca9e39046acb8/test.txt'

# %% [markdown]
# - move data

# %%
# !cp -f /home/jovyan/UltraGCN/data/Gowalla_m1/datasets--reczoo--Gowalla_m1/snapshots/d18cf8efd0f159548cd674c7320ca9e39046acb8/train.txt /home/jovyan/UltraGCN/data/Gowalla_m1/


# !cp -f /home/jovyan/UltraGCN/data/Gowalla_m1/datasets--reczoo--Gowalla_m1/snapshots/d18cf8efd0f159548cd674c7320ca9e39046acb8/test.txt /home/jovyan/UltraGCN/data/Gowalla_m1/

# %% [markdown]
# ## AmazonBooks_m1
#
# + **Dataset description:**
#
#   The data statistics are summarized as follows:
#
#   | Dataset ID     | #Users | #Items | #Interactions |   #Train  |  #Test  | Density |
#   |:--------------:|:------:|:------:|:-------------:|:---------:|:-------:|:-------:|
#   | AmazonBooks_m1 | 52,643 | 91,599 |   2,984,108   | 2,380,730 | 603,378 | 0.00062 |
#
#
# + **Data format:**
# user_id item1 item2 ...
#
# + **Source:** https://cseweb.ucsd.edu/~jmcauley/datasets.html
# + **Download:** https://huggingface.co/datasets/reczoo/AmazonBooks_m1/tree/main
# + **RecZoo Datasets:** https://github.com/reczoo/Datasets
#
# + **Check the md5sum for data integrity:**
#     ```bash
#     $ md5sum *.txt
#     5b1125ef3bf4118a7988f1fd8ce52ef9  item_list.txt
#     30f8ccfea18d25007ba9fb9aba4e174d  test.txt
#     c916ecac04ca72300a016228258b41ed  train.txt
#     132f8a5d6d35d5fdde1e0396488be235  user_list.txt
#     ```

# %% [markdown]
# - Train data

# %%
hf_hub_download(repo_id="reczoo/AmazonBooks_m1", filename="train.txt", repo_type="dataset", cache_dir="./data/AmazonBooks_m1")
# Out:
# train.txt:   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# './data/AmazonBooks_m1/datasets--reczoo--AmazonBooks_m1/snapshots/69008aca172fea74b441667e759213a4c0591a4e/train.txt'

# %% [markdown]
# - Test data

# %%
hf_hub_download(repo_id="reczoo/AmazonBooks_m1", filename="test.txt", repo_type="dataset", cache_dir="./data/AmazonBooks_m1")
# Out:
# test.txt:   0%|          | 0.00/3.85M [00:00<?, ?B/s]
# './data/AmazonBooks_m1/datasets--reczoo--AmazonBooks_m1/snapshots/69008aca172fea74b441667e759213a4c0591a4e/test.txt'

# %% [markdown]
# - move data

# %%
# !cp -f /home/jovyan/UltraGCN/data/AmazonBooks_m1/datasets--reczoo--AmazonBooks_m1/snapshots/69008aca172fea74b441667e759213a4c0591a4e/train.txt /home/jovyan/UltraGCN/data/AmazonBooks_m1/

# !cp -f /home/jovyan/UltraGCN/data/AmazonBooks_m1/datasets--reczoo--AmazonBooks_m1/snapshots/69008aca172fea74b441667e759213a4c0591a4e/test.txt /home/jovyan/UltraGCN/data/AmazonBooks_m1/

# %% [markdown]
# # Movielens1M_m1
#
# + **Dataset description:**
#
#   The MovieLens-1M dataset contain 1,000,209 anonymous ratings of approximately 3,900 movies made by 6,040 MovieLens users. We follow the LCF work to split and preprocess the data into training, validation, and test sets, respectively.
#
# + **Data format:**
#
#   Each user corresponds to a list of interacted items: [[item1, item2], [item3, item4, item5], ...]
#
# + **Source:** https://grouplens.org/datasets/movielens/1m/
# + **Download:** https://huggingface.co/datasets/reczoo/Movielens1M_m1/tree/main
# + **RecZoo Datasets:** https://github.com/reczoo/Datasets
#
# + **Check the md5sum for data integrity:**
#   ```bash
#   $ md5sum *.json
#   cdd3ad819512cb87dad2f098c8437df2  test_data.json
#   4229bc5369f943918103daf7fd92e920  train_data.json
#   60be3b377d39806f80a43e37c94449f6  validation_data.json
#   ```

# %% [markdown]
# - Train data

# %%
hf_hub_download(repo_id="reczoo/Movielens1M_m1", filename="train_data.json", repo_type="dataset", cache_dir="./data/Movielens1M_m1")
# Out:
# train_data.json:   0%|          | 0.00/4.44M [00:00<?, ?B/s]
# './data/Movielens1M_m1/datasets--reczoo--Movielens1M_m1/snapshots/1186acccb5a9d3efb310a9dd842a65cc4b666c60/train_data.json'

# %% [markdown]
# - Test data

# %%
hf_hub_download(repo_id="reczoo/Movielens1M_m1", filename="test_data.json", repo_type="dataset", cache_dir="./data/Movielens1M_m1")
# Out:
# test_data.json:   0%|          | 0.00/565k [00:00<?, ?B/s]
# './data/Movielens1M_m1/datasets--reczoo--Movielens1M_m1/snapshots/1186acccb5a9d3efb310a9dd842a65cc4b666c60/test_data.json'

# %% [markdown]
# - move data

# %%
# !cp -f /home/jovyan/UltraGCN/data/Movielens1M_m1/datasets--reczoo--Movielens1M_m1/snapshots/1186acccb5a9d3efb310a9dd842a65cc4b666c60/train_data.json /home/jovyan/UltraGCN/data/Movielens1M_m1/

# !cp -f /home/jovyan/UltraGCN/data/Movielens1M_m1/datasets--reczoo--Movielens1M_m1/snapshots/1186acccb5a9d3efb310a9dd842a65cc4b666c60/test_data.json /home/jovyan/UltraGCN/data/Movielens1M_m1/

# %% [markdown]
# ## AmazonElectronics_m1
#
# + **Data format:**
#
#   Each user corresponds to a list of interacted items: [[item1, item2], [item3, item4, item5], ...]
#
# + **Source:** https://cseweb.ucsd.edu/~jmcauley/datasets.html
# + **Download:** https://huggingface.co/datasets/reczoo/AmazonElectronics_m1/tree/main
# + **RecZoo Datasets:** https://github.com/reczoo/Datasets
#
# + **Check the md5sum for data integrity:**
#     ```bash
#     $ md5sum *.json
#     7a0fa5d0da5dc5d5008da02b554ef688  test_data.json
#     ca71f3f5b9ada393ffd5490eba84c7db  train_data.json
#     7f2db9b5b0de91c7d757ed6ed6095a5a  validation_data.json
#     ```

# %% [markdown]
# - Train data

# %%
hf_hub_download(repo_id="reczoo/AmazonElectronics_m1", filename="train_data.json", repo_type="dataset", cache_dir="./data/AmazonElectronics_m1")
# Out:
# train_data.json:   0%|          | 0.00/171k [00:00<?, ?B/s]
# './data/AmazonElectronics_m1/datasets--reczoo--AmazonElectronics_m1/snapshots/d6951f1a171149ebb7729505984bbed2d4ab653a/train_data.json'

# %% [markdown]
# - Test data

# %%
hf_hub_download(repo_id="reczoo/AmazonElectronics_m1", filename="test_data.json", repo_type="dataset", cache_dir="./data/AmazonElectronics_m1")
# Out:
# test_data.json:   0%|          | 0.00/24.2k [00:00<?, ?B/s]
# './data/AmazonElectronics_m1/datasets--reczoo--AmazonElectronics_m1/snapshots/d6951f1a171149ebb7729505984bbed2d4ab653a/test_data.json'

# %% [markdown]
# - move data

# %%
# !cp -f /home/jovyan/UltraGCN/data/AmazonElectronics_m1/datasets--reczoo--AmazonElectronics_m1/snapshots/d6951f1a171149ebb7729505984bbed2d4ab653a/train_data.json /home/jovyan/UltraGCN/data/AmazonElectronics_m1/

# !cp -f /home/jovyan/UltraGCN/data/AmazonElectronics_m1/datasets--reczoo--AmazonElectronics_m1/snapshots/d6951f1a171149ebb7729505984bbed2d4ab653a/test_data.json /home/jovyan/UltraGCN/data/AmazonElectronics_m1/

# %% [markdown]
# ## AmazonCDs_m1
#
# + **Data format:**
# user_id item1 item2 ...
#
# + **Source:** https://cseweb.ucsd.edu/~jmcauley/datasets.html
# + **Download:** https://huggingface.co/datasets/reczoo/AmazonCDs_m1/tree/main
# + **RecZoo Datasets:** https://github.com/reczoo/Datasets
#
# + **Check the md5sum for data integrity:**
#     ```bash
#     $ md5sum *.txt
#     d29acb66d0fb74bc3bc0791cbbce5cf2  test.txt
#     2df6a35cac4373cf3eef95f75568da0a  train.txt
#     ```

# %% [markdown]
# - Train data

# %%
hf_hub_download(repo_id="reczoo/AmazonCDs_m1", filename="train.txt", repo_type="dataset", cache_dir="./data/AmazonCDs_m1")
# Out:
# train.txt:   0%|          | 0.00/3.69M [00:00<?, ?B/s]
# './data/AmazonCDs_m1/datasets--reczoo--AmazonCDs_m1/snapshots/ff4ac583bc5399b59234278fa5398b86061d0b61/train.txt'

# %% [markdown]
# - Test data

# %%
hf_hub_download(repo_id="reczoo/AmazonCDs_m1", filename="test.txt", repo_type="dataset", cache_dir="./data/AmazonCDs_m1")
# Out:
# test.txt:   0%|          | 0.00/1.23M [00:00<?, ?B/s]
# './data/AmazonCDs_m1/datasets--reczoo--AmazonCDs_m1/snapshots/ff4ac583bc5399b59234278fa5398b86061d0b61/test.txt'

# %% [markdown]
# - move data

# %%
# !cp -f /home/jovyan/UltraGCN/data/AmazonCDs_m1/datasets--reczoo--AmazonCDs_m1/snapshots/ff4ac583bc5399b59234278fa5398b86061d0b61/train.txt /home/jovyan/UltraGCN/data/AmazonCDs_m1/

# !cp -f /home/jovyan/UltraGCN/data/AmazonCDs_m1/datasets--reczoo--AmazonCDs_m1/snapshots/ff4ac583bc5399b59234278fa5398b86061d0b61/test.txt /home/jovyan/UltraGCN/data/AmazonCDs_m1/

# %% [markdown]
# - delete junk folders

# %%
# !rm -r /home/jovyan/UltraGCN/data/AmazonBooks_m1/datasets--reczoo--*
# !rm -r /home/jovyan/UltraGCN/data/AmazonCDs_m1/datasets--reczoo--*
# !rm -r /home/jovyan/UltraGCN/data/AmazonElectronics_m1/datasets--reczoo--*
# !rm -r /home/jovyan/UltraGCN/data/Gowalla_m1/datasets--reczoo--*
# !rm -r /home/jovyan/UltraGCN/data/Movielens1M_m1/datasets--reczoo--*
# !rm -r /home/jovyan/UltraGCN/data/Yelp18_m1/datasets--reczoo--*
